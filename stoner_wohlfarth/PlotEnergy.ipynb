# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
energy_data = np.genfromtxt("run/totenergy.EXP_NAME.out")
avrg_data = np.genfromtxt("run/averages.EXP_NAME.out")

# %%
Mzs = avrg_data[1:-1, 3]
Es = energy_data[1:, 1]
JEs = energy_data[1:, 2]
DMEs = energy_data[1:, 4]

# %%
plt.figure(figsize=(10, 6))

plt.scatter(Mzs, JEs + DMEs)

# %%
plt.figure(figsize=(10, 6))

plt.scatter(Mzs, JEs + DMEs)
